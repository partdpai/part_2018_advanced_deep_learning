# %% [markdown]
# # Load images from folder

# %%
from __future__ import print_function, division
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets

dataset = datasets.ImageFolder(root='faces')#path for input folder
print(dataset[0][0])

plt.imshow(dataset[4][0])

trainloader = torch.utils.data.DataLoader(dataset, batch_size=4,
                                          shuffle=True, num_workers=2)
# Out:
# <PIL.Image.Image image mode=RGB size=215x324 at 0x7F02D01529E8>

# %% [markdown]
# # write your own dataloader class

# %%
from torch.utils.data import Dataset


class MyDataSet(Dataset):
    def __init__(self):
        super().__init__()
        
    def __len__(self):
        return 0
    
    def __getitem__(self, idx):
        return None
